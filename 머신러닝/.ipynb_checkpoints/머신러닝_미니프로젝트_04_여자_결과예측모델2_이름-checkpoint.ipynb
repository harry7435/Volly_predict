# %%
import pandas as pd

# %%
df_data = pd.read_csv('./train_female.csv')
df_predict = pd.read_csv('./test_female.csv')
df_data.drop(['Unnamed: 0'], axis = 1, inplace = True)
df_predict.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
df_data
# Out:
#      결과  득점_득점   공격종합성공률     후위성공률    퀵오픈성공률     서브성공률     디그성공률     세트성공률  \
# 0     1     88  0.413793  0.444444  0.423077  0.082569  0.839286  0.374302
# 1     0     83  0.422360  0.592593  0.551020  0.096154  0.789474  0.402439
# 2     0     39  0.358696  0.450000  0.300000  0.046512  0.811321  0.324074
# 3     0     47  0.401961  0.533333  0.517241  0.078431  0.881356  0.405941
# 4     1     85  0.458065  0.400000  0.619048  0.018519  0.816327  0.421384
# ..   ..    ...       ...       ...       ...       ...       ...       ...
# 943   0     37  0.357143  0.250000  0.423077  0.022222  0.756098  0.190476
# 944   0     58  0.316770  0.142857  0.400000  0.054795  0.839286  0.311258
# 945   1     62  0.413793  0.357143  0.520000  0.082192  0.804878  0.360360
# 946   0     60  0.327044  0.153846  0.379310  0.037037  0.862385  0.308642
# 947   0     37  0.300971  0.222222  0.280000  0.061224  0.796875  0.245098
#
#        리시브성공률    블로킹성공률  ...  팀명_한국도로공사  팀명_현대건설  팀명_흥국생명  상대팀_GS칼텍스  \
# 0    0.443299  0.097222  ...          0        0        0          0
# 1    0.421053  0.084746  ...          0        0        0          0
# 2    0.666667  0.181818  ...          0        0        0          0
# 3    0.389831  0.058824  ...          0        0        0          0
# 4    0.467391  0.181818  ...          0        0        0          0
# ..        ...       ...  ...        ...      ...      ...        ...
# 943  0.267857  0.157895  ...          0        0        1          1
# 944  0.246753  0.058824  ...          0        0        1          0
# 945  0.392857  0.163265  ...          0        0        1          0
# 946  0.382716  0.062500  ...          0        0        1          0
# 947  0.245902  0.063830  ...          0        0        1          0
#
#      상대팀_IBK기업은행  상대팀_KGC인삼공사  상대팀_페퍼저축은행  상대팀_한국도로공사  상대팀_현대건설  상대팀_흥국생명
# 0              0            0           0           1         0         0
# 1              0            1           0           0         0         0
# 2              0            0           0           0         1         0
# 3              1            0           0           0         0         0
# 4              0            0           0           0         0         1
# ..           ...          ...         ...         ...       ...       ...
# 943            0            0           0           0         0         0
# 944            0            0           0           1         0         0
# 945            0            1           0           0         0         0
# 946            0            0           1           0         0         0
# 947            1            0           0           0         0         0
#
# [948 rows x 24 columns]

# %%
df_data.columns
# Out:
# Index(['결과', '득점_득점', '공격종합성공률', '후위성공률', '퀵오픈성공률', '서브성공률', '디그성공률', '세트성공률',
#        '리시브성공률', '블로킹성공률', '팀명_GS칼텍스', '팀명_IBK기업은행', '팀명_KGC인삼공사', '팀명_페퍼저축은행',
#        '팀명_한국도로공사', '팀명_현대건설', '팀명_흥국생명', '상대팀_GS칼텍스', '상대팀_IBK기업은행',
#        '상대팀_KGC인삼공사', '상대팀_페퍼저축은행', '상대팀_한국도로공사', '상대팀_현대건설', '상대팀_흥국생명'],
#       dtype='object')

# %%
GS칼텍스 = df_data[df_data['팀명_GS칼텍스'] == 1]

IBK기업은행 = df_data[df_data['팀명_IBK기업은행'] == 1]

KGC인삼공사 = df_data[df_data['팀명_KGC인삼공사'] == 1]

페퍼저축은행 = df_data[df_data['팀명_페퍼저축은행'] == 1]

한국도로공사 = df_data[df_data['팀명_한국도로공사'] == 1]

현대건설 = df_data[df_data['팀명_현대건설'] == 1]

흥국생명 = df_data[df_data['팀명_흥국생명'] == 1]

# %%
GS칼텍스 = GS칼텍스.drop(columns=['팀명_GS칼텍스', '팀명_IBK기업은행', '팀명_KGC인삼공사', '팀명_페퍼저축은행',
       '팀명_한국도로공사', '팀명_현대건설', '팀명_흥국생명', '상대팀_GS칼텍스'])

IBK기업은행 = IBK기업은행.drop(columns=['팀명_GS칼텍스', '팀명_IBK기업은행', '팀명_KGC인삼공사', '팀명_페퍼저축은행',
       '팀명_한국도로공사', '팀명_현대건설', '팀명_흥국생명', '상대팀_IBK기업은행'])

KGC인삼공사 = KGC인삼공사.drop(columns=['팀명_GS칼텍스', '팀명_IBK기업은행', '팀명_KGC인삼공사', '팀명_페퍼저축은행',
       '팀명_한국도로공사', '팀명_현대건설', '팀명_흥국생명', '상대팀_KGC인삼공사'])

페퍼저축은행 = 페퍼저축은행.drop(columns=['팀명_GS칼텍스', '팀명_IBK기업은행', '팀명_KGC인삼공사', '팀명_페퍼저축은행',
       '팀명_한국도로공사', '팀명_현대건설', '팀명_흥국생명', '상대팀_페퍼저축은행'])

한국도로공사 = 한국도로공사.drop(columns=['팀명_GS칼텍스', '팀명_IBK기업은행', '팀명_KGC인삼공사', '팀명_페퍼저축은행',
       '팀명_한국도로공사', '팀명_현대건설', '팀명_흥국생명', '상대팀_한국도로공사'])

현대건설 = 현대건설.drop(columns=['팀명_GS칼텍스', '팀명_IBK기업은행', '팀명_KGC인삼공사', '팀명_페퍼저축은행',
       '팀명_한국도로공사', '팀명_현대건설', '팀명_흥국생명', '상대팀_현대건설'])

흥국생명 = 흥국생명.drop(columns=['팀명_GS칼텍스', '팀명_IBK기업은행', '팀명_KGC인삼공사', '팀명_페퍼저축은행',
       '팀명_한국도로공사', '팀명_현대건설', '팀명_흥국생명', '상대팀_흥국생명'])

# %%
흥국생명
# Out:
#      결과  득점_득점   공격종합성공률     후위성공률    퀵오픈성공률     서브성공률     디그성공률     세트성공률  \
# 791   1     82  0.328125  0.428571  0.400000  0.047619  0.861111  0.312821
# 792   1     86  0.398810  0.533333  0.428571  0.077670  0.880734  0.366279
# 793   0     31  0.291667  0.300000  0.600000  0.025641  0.867925  0.255556
# 794   0     40  0.290598  0.318182  0.166667  0.037736  0.860759  0.282443
# 795   0     73  0.406250  0.333333  0.263158  0.039216  0.788991  0.354286
# ..   ..    ...       ...       ...       ...       ...       ...       ...
# 943   0     37  0.357143  0.250000  0.423077  0.022222  0.756098  0.190476
# 944   0     58  0.316770  0.142857  0.400000  0.054795  0.839286  0.311258
# 945   1     62  0.413793  0.357143  0.520000  0.082192  0.804878  0.360360
# 946   0     60  0.327044  0.153846  0.379310  0.037037  0.862385  0.308642
# 947   0     37  0.300971  0.222222  0.280000  0.061224  0.796875  0.245098
#
#        리시브성공률    블로킹성공률  상대팀_GS칼텍스  상대팀_IBK기업은행  상대팀_KGC인삼공사  상대팀_페퍼저축은행  \
# 791  0.505882  0.200000          0            1            0           0
# 792  0.400000  0.177419          0            0            1           0
# 793  0.454545  0.111111          0            0            0           0
# 794  0.476190  0.133333          0            0            0           0
# 795  0.404040  0.074074          1            0            0           0
# ..        ...       ...        ...          ...          ...         ...
# 943  0.267857  0.157895          1            0            0           0
# 944  0.246753  0.058824          0            0            0           0
# 945  0.392857  0.163265          0            0            1           0
# 946  0.382716  0.062500          0            0            0           1
# 947  0.245902  0.063830          0            1            0           0
#
#      상대팀_한국도로공사  상대팀_현대건설
# 791           0         0
# 792           0         0
# 793           0         1
# 794           1         0
# 795           0         0
# ..          ...       ...
# 943           0         0
# 944           1         0
# 945           0         0
# 946           0         0
# 947           0         0
#
# [157 rows x 16 columns]

# %%
GS칼텍스_predict = df_predict[df_predict['팀명_GS칼텍스'] == 1]

IBK기업은행_predict = df_predict[df_predict['팀명_IBK기업은행'] == 1]

KGC인삼공사_predict = df_predict[df_predict['팀명_KGC인삼공사'] == 1]

페퍼저축은행_predict = df_predict[df_predict['팀명_페퍼저축은행'] == 1]

한국도로공사_predict = df_predict[df_predict['팀명_한국도로공사'] == 1]

현대건설_predict = df_predict[df_predict['팀명_현대건설'] == 1]

흥국생명_predict = df_predict[df_predict['팀명_흥국생명'] == 1]

# %%
GS칼텍스_predict = GS칼텍스_predict.drop(columns=['팀명_GS칼텍스', '팀명_IBK기업은행', '팀명_KGC인삼공사', '팀명_페퍼저축은행',
       '팀명_한국도로공사', '팀명_현대건설', '팀명_흥국생명', '상대팀_GS칼텍스'])

IBK기업은행_predict = IBK기업은행_predict.drop(columns=['팀명_GS칼텍스', '팀명_IBK기업은행', '팀명_KGC인삼공사', '팀명_페퍼저축은행',
       '팀명_한국도로공사', '팀명_현대건설', '팀명_흥국생명', '상대팀_IBK기업은행'])

KGC인삼공사_predict = KGC인삼공사_predict.drop(columns=['팀명_GS칼텍스', '팀명_IBK기업은행', '팀명_KGC인삼공사', '팀명_페퍼저축은행',
       '팀명_한국도로공사', '팀명_현대건설', '팀명_흥국생명', '상대팀_KGC인삼공사'])

페퍼저축은행_predict = 페퍼저축은행_predict.drop(columns=['팀명_GS칼텍스', '팀명_IBK기업은행', '팀명_KGC인삼공사', '팀명_페퍼저축은행',
       '팀명_한국도로공사', '팀명_현대건설', '팀명_흥국생명', '상대팀_페퍼저축은행'])

한국도로공사_predict = 한국도로공사_predict.drop(columns=['팀명_GS칼텍스', '팀명_IBK기업은행', '팀명_KGC인삼공사', '팀명_페퍼저축은행',
       '팀명_한국도로공사', '팀명_현대건설', '팀명_흥국생명', '상대팀_한국도로공사'])

현대건설_predict = 현대건설_predict.drop(columns=['팀명_GS칼텍스', '팀명_IBK기업은행', '팀명_KGC인삼공사', '팀명_페퍼저축은행',
       '팀명_한국도로공사', '팀명_현대건설', '팀명_흥국생명', '상대팀_현대건설'])

흥국생명_predict = 흥국생명_predict.drop(columns=['팀명_GS칼텍스', '팀명_IBK기업은행', '팀명_KGC인삼공사', '팀명_페퍼저축은행',
       '팀명_한국도로공사', '팀명_현대건설', '팀명_흥국생명', '상대팀_흥국생명'])

# %%
GS칼텍스_predict =GS칼텍스_predict.reset_index().drop(columns='index')

IBK기업은행_predict =IBK기업은행_predict.reset_index().drop(columns='index')

KGC인삼공사_predict =KGC인삼공사_predict.reset_index().drop(columns='index')

페퍼저축은행_predict =페퍼저축은행_predict.reset_index().drop(columns='index')

한국도로공사_predict =한국도로공사_predict.reset_index().drop(columns='index')

현대건설_predict =현대건설_predict.reset_index().drop(columns='index')

흥국생명_predict =흥국생명_predict.reset_index().drop(columns='index')

# %% [markdown]
# 팀별 학습 진행후, 제일 좋은 모델을 기반으로
# 팀, 상대팀 입력
# 팀의 스탯은 평균값을 중심으로 min~max 범위내로 조정해서 함수 입력
# 상대팀과의 상성과 임의로 주어진 스탯을 중심으로 승패 계산

# %% [markdown]
# # 각 팀 별 모델 만들기

# %%
from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier


lgb = LGBMClassifier(bagging_fraction=0.9, bagging_freq=3, boosting_type='gbdt',
                class_weight=None, feature_fraction=0.5,
                importance_type='split', learning_rate=0.4, max_depth=-1,
                min_child_samples=6, min_child_weight=0.001, min_split_gain=0.3,
                n_estimators=20, n_jobs=-1, num_leaves=150, objective=None,
                random_state=0, reg_alpha=0.005, reg_lambda=0.0005,
                silent='warn', subsample_for_bin=200000)
rf = RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
                        class_weight='balanced_subsample', criterion='entropy',
                        max_depth=4, max_features='log2', max_leaf_nodes=None,
                        max_samples=None, min_impurity_decrease=0.0002,
                        min_samples_leaf=5,
                        min_samples_split=9, min_weight_fraction_leaf=0.0,
                        n_estimators=130, n_jobs=-1, oob_score=False,
                        random_state=0, verbose=0, warm_start=False)
gbc = GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
                            learning_rate=0.01, loss='log_loss', max_depth=7,
                            max_features='sqrt', max_leaf_nodes=None,
                            min_impurity_decrease=0.05,
                            min_samples_leaf=2, min_samples_split=2,
                            min_weight_fraction_leaf=0.0, n_estimators=140,
                            n_iter_no_change=None,
                            random_state=0, subsample=0.35, tol=0.0001,
                            validation_fraction=0.1, verbose=0,
                            warm_start=False)

# %%
# GS칼텍스 

model_GS = VotingClassifier([('lgb', lgb), ('rf',rf), ('gbc',gbc)], voting= 'soft')
X= GS칼텍스.drop(columns=['결과'])
y = GS칼텍스['결과']
model_GS.fit(X,y)
# Out:
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# VotingClassifier(estimators=[('lgb',
#                               LGBMClassifier(bagging_fraction=0.9,
#                                              bagging_freq=3,
#                                              feature_fraction=0.5,
#                                              learning_rate=0.4,
#                                              min_child_samples=6,
#                                              min_split_gain=0.3,
#                                              n_estimators=20, num_leaves=150,
#                                              random_state=0, reg_alpha=0.005,
#                                              reg_lambda=0.0005)),
#                              ('rf',
#                               RandomForestClassifier(class_weight='balanced_subsample',
#                                                      criterion='entropy',
#                                                      max_depth=4,
#                                                      max_features='log2',
#                                                      min_impurity_decrease=0.0002,
#                                                      min_samples_leaf=5,
#                                                      min_samples_split=9,
#                                                      n_estimators=130,
#                                                      n_jobs=-1,
#                                                      random_state=0)),
#                              ('gbc',
#                               GradientBoostingClassifier(learning_rate=0.01,
#                                                          max_depth=7,
#                                                          max_features='sqrt',
#                                                          min_impurity_decrease=0.05,
#                                                          min_samples_leaf=2,
#                                                          n_estimators=140,
#                                                          random_state=0,
#                                                          subsample=0.35))],
#                  voting='soft')

# %%
#흥국생명 

model_흥국 = VotingClassifier([('lgb', lgb), ('rf',rf), ('gbc',gbc)], voting= 'soft')
X= 흥국생명.drop(columns=['결과'])
y = 흥국생명['결과']
model_흥국.fit(X,y)
# Out:
# VotingClassifier(estimators=[('lgb',
#                               LGBMClassifier(bagging_fraction=0.9,
#                                              bagging_freq=3,
#                                              feature_fraction=0.5,
#                                              learning_rate=0.4,
#                                              min_child_samples=6,
#                                              min_split_gain=0.3,
#                                              n_estimators=20, num_leaves=150,
#                                              random_state=0, reg_alpha=0.005,
#                                              reg_lambda=0.0005)),
#                              ('rf',
#                               RandomForestClassifier(class_weight='balanced_subsample',
#                                                      criterion='entropy',
#                                                      max_depth=4,
#                                                      max_features='log2',
#                                                      min_impurity_decrease=0.0002,
#                                                      min_samples_leaf=5,
#                                                      min_samples_split=9,
#                                                      n_estimators=130,
#                                                      n_jobs=-1,
#                                                      random_state=0)),
#                              ('gbc',
#                               GradientBoostingClassifier(learning_rate=0.01,
#                                                          max_depth=7,
#                                                          max_features='sqrt',
#                                                          min_impurity_decrease=0.05,
#                                                          min_samples_leaf=2,
#                                                          n_estimators=140,
#                                                          random_state=0,
#                                                          subsample=0.35))],
#                  voting='soft')

# %%
#IBK기업은행

model_IBK = VotingClassifier([('lgb', lgb), ('rf',rf), ('gbc',gbc)], voting= 'soft')
X= IBK기업은행.drop(columns=['결과'])
y = IBK기업은행['결과']
model_IBK.fit(X,y)
# Out:
# VotingClassifier(estimators=[('lgb',
#                               LGBMClassifier(bagging_fraction=0.9,
#                                              bagging_freq=3,
#                                              feature_fraction=0.5,
#                                              learning_rate=0.4,
#                                              min_child_samples=6,
#                                              min_split_gain=0.3,
#                                              n_estimators=20, num_leaves=150,
#                                              random_state=0, reg_alpha=0.005,
#                                              reg_lambda=0.0005)),
#                              ('rf',
#                               RandomForestClassifier(class_weight='balanced_subsample',
#                                                      criterion='entropy',
#                                                      max_depth=4,
#                                                      max_features='log2',
#                                                      min_impurity_decrease=0.0002,
#                                                      min_samples_leaf=5,
#                                                      min_samples_split=9,
#                                                      n_estimators=130,
#                                                      n_jobs=-1,
#                                                      random_state=0)),
#                              ('gbc',
#                               GradientBoostingClassifier(learning_rate=0.01,
#                                                          max_depth=7,
#                                                          max_features='sqrt',
#                                                          min_impurity_decrease=0.05,
#                                                          min_samples_leaf=2,
#                                                          n_estimators=140,
#                                                          random_state=0,
#                                                          subsample=0.35))],
#                  voting='soft')

# %%
#KGC인삼공사 

model_KGC = VotingClassifier([('lgb', lgb), ('rf',rf), ('gbc',gbc)], voting= 'soft')
X= KGC인삼공사.drop(columns=['결과'])
y = KGC인삼공사['결과']
model_KGC.fit(X,y)
# Out:
# VotingClassifier(estimators=[('lgb',
#                               LGBMClassifier(bagging_fraction=0.9,
#                                              bagging_freq=3,
#                                              feature_fraction=0.5,
#                                              learning_rate=0.4,
#                                              min_child_samples=6,
#                                              min_split_gain=0.3,
#                                              n_estimators=20, num_leaves=150,
#                                              random_state=0, reg_alpha=0.005,
#                                              reg_lambda=0.0005)),
#                              ('rf',
#                               RandomForestClassifier(class_weight='balanced_subsample',
#                                                      criterion='entropy',
#                                                      max_depth=4,
#                                                      max_features='log2',
#                                                      min_impurity_decrease=0.0002,
#                                                      min_samples_leaf=5,
#                                                      min_samples_split=9,
#                                                      n_estimators=130,
#                                                      n_jobs=-1,
#                                                      random_state=0)),
#                              ('gbc',
#                               GradientBoostingClassifier(learning_rate=0.01,
#                                                          max_depth=7,
#                                                          max_features='sqrt',
#                                                          min_impurity_decrease=0.05,
#                                                          min_samples_leaf=2,
#                                                          n_estimators=140,
#                                                          random_state=0,
#                                                          subsample=0.35))],
#                  voting='soft')

# %%
#페퍼저축은행 

model_페퍼 = VotingClassifier([('lgb', lgb), ('rf',rf), ('gbc',gbc)], voting= 'soft')
X= 페퍼저축은행.drop(columns=['결과'])
y = 페퍼저축은행['결과']
model_페퍼.fit(X,y)
# Out:
# VotingClassifier(estimators=[('lgb',
#                               LGBMClassifier(bagging_fraction=0.9,
#                                              bagging_freq=3,
#                                              feature_fraction=0.5,
#                                              learning_rate=0.4,
#                                              min_child_samples=6,
#                                              min_split_gain=0.3,
#                                              n_estimators=20, num_leaves=150,
#                                              random_state=0, reg_alpha=0.005,
#                                              reg_lambda=0.0005)),
#                              ('rf',
#                               RandomForestClassifier(class_weight='balanced_subsample',
#                                                      criterion='entropy',
#                                                      max_depth=4,
#                                                      max_features='log2',
#                                                      min_impurity_decrease=0.0002,
#                                                      min_samples_leaf=5,
#                                                      min_samples_split=9,
#                                                      n_estimators=130,
#                                                      n_jobs=-1,
#                                                      random_state=0)),
#                              ('gbc',
#                               GradientBoostingClassifier(learning_rate=0.01,
#                                                          max_depth=7,
#                                                          max_features='sqrt',
#                                                          min_impurity_decrease=0.05,
#                                                          min_samples_leaf=2,
#                                                          n_estimators=140,
#                                                          random_state=0,
#                                                          subsample=0.35))],
#                  voting='soft')

# %%
#한국도로공사 

model_도로 = VotingClassifier([('lgb', lgb), ('rf',rf), ('gbc',gbc)], voting= 'soft')
X= 한국도로공사.drop(columns=['결과'])
y = 한국도로공사['결과']
model_도로.fit(X,y)
# Out:
# VotingClassifier(estimators=[('lgb',
#                               LGBMClassifier(bagging_fraction=0.9,
#                                              bagging_freq=3,
#                                              feature_fraction=0.5,
#                                              learning_rate=0.4,
#                                              min_child_samples=6,
#                                              min_split_gain=0.3,
#                                              n_estimators=20, num_leaves=150,
#                                              random_state=0, reg_alpha=0.005,
#                                              reg_lambda=0.0005)),
#                              ('rf',
#                               RandomForestClassifier(class_weight='balanced_subsample',
#                                                      criterion='entropy',
#                                                      max_depth=4,
#                                                      max_features='log2',
#                                                      min_impurity_decrease=0.0002,
#                                                      min_samples_leaf=5,
#                                                      min_samples_split=9,
#                                                      n_estimators=130,
#                                                      n_jobs=-1,
#                                                      random_state=0)),
#                              ('gbc',
#                               GradientBoostingClassifier(learning_rate=0.01,
#                                                          max_depth=7,
#                                                          max_features='sqrt',
#                                                          min_impurity_decrease=0.05,
#                                                          min_samples_leaf=2,
#                                                          n_estimators=140,
#                                                          random_state=0,
#                                                          subsample=0.35))],
#                  voting='soft')

# %%
#현대건설 

model_현대 = VotingClassifier([('lgb', lgb), ('rf',rf), ('gbc',gbc)], voting= 'soft')
X= 현대건설.drop(columns=['결과'])
y = 현대건설['결과']
model_현대.fit(X,y)
# Out:
# VotingClassifier(estimators=[('lgb',
#                               LGBMClassifier(bagging_fraction=0.9,
#                                              bagging_freq=3,
#                                              feature_fraction=0.5,
#                                              learning_rate=0.4,
#                                              min_child_samples=6,
#                                              min_split_gain=0.3,
#                                              n_estimators=20, num_leaves=150,
#                                              random_state=0, reg_alpha=0.005,
#                                              reg_lambda=0.0005)),
#                              ('rf',
#                               RandomForestClassifier(class_weight='balanced_subsample',
#                                                      criterion='entropy',
#                                                      max_depth=4,
#                                                      max_features='log2',
#                                                      min_impurity_decrease=0.0002,
#                                                      min_samples_leaf=5,
#                                                      min_samples_split=9,
#                                                      n_estimators=130,
#                                                      n_jobs=-1,
#                                                      random_state=0)),
#                              ('gbc',
#                               GradientBoostingClassifier(learning_rate=0.01,
#                                                          max_depth=7,
#                                                          max_features='sqrt',
#                                                          min_impurity_decrease=0.05,
#                                                          min_samples_leaf=2,
#                                                          n_estimators=140,
#                                                          random_state=0,
#                                                          subsample=0.35))],
#                  voting='soft')

# %% [markdown]
# 입력예시: 흥국생명, 흥국생명_predict

# %%
predict_data = 흥국생명_predict.drop(columns=['결과'])

# %%
pred = model_흥국.predict(predict_data)

# %%
def winning_predict( model,x=predict_data,):
    win_lose = model.predict(x)
    for i in range(len(win_lose)):
        if win_lose[i] == 1:
            if x.iloc[i,9] == 1:
                print(f'{x.columns[9]}에게 승리')
            elif x.iloc[i,10] == 1:
                print(f'{x.columns[10]}에게 승리')            
            elif x.iloc[i,11] == 1:
                print(f'{x.columns[11]}에게 승리')
            elif x.iloc[i,12] == 1:
                print(f'{x.columns[12]}에게 승리')
            elif x.iloc[i,13] == 1:
                    print(f'{x.columns[13]}에게 승리')    
            elif x.iloc[i,14] == 1:
                    print(f'{x.columns[14]}에게 승리')    
        else:
            if x.iloc[i,9] == 1:
                print(f'{x.columns[9]}에게 패배')
            elif x.iloc[i,10] == 1:
                print(f'{x.columns[10]}에게 패배')            
            elif x.iloc[i,11] == 1:
                print(f'{x.columns[11]}에게 패배')
            elif x.iloc[i,12] == 1:
                print(f'{x.columns[12]}에게 패배')
            elif x.iloc[i,13] == 1:
                print(f'{x.columns[13]}에게 패배')    
            elif x.iloc[i,14] == 1:
                print(f'{x.columns[14]}에게 패배')

# %%
winning_predict(model_흥국)
# Out:
# 상대팀_IBK기업은행에게 패배
# 상대팀_한국도로공사에게 패배
# 상대팀_GS칼텍스에게 패배

# %%
len(흥국생명_predict[흥국생명_predict['결과'] == pred]) / len(흥국생명_predict)
# Out:
# 0.6666666666666666
